# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 KB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 39.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 10.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.0.1
#     Uninstalling html5lib-1.0.1:
#       Successfully uninstalled html5lib-1.0.1
#   Attempting uninstall: beautifulsoup4
# ...

# %%
# !pip install yahoofinancials
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for yahoofinancials: filename=yahoofinancials-1.13-py3-none-any.whl size=28680 sha256=fb9e7ca28414eb9c7adbbc282c66e9fb96128f67f1805ad3600fc4fd040ed0c5
#   Stored in directory: /root/.cache/pip/wheels/fa/18/39/f4baa14addcd0d6c4e9358f12591adefc6f05a11dd689e7df0
# Successfully built yahoofinancials
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from yahoofinancials import YahooFinancials
import pandas as pd
from datetime import datetime
today=datetime.today().strftime('%Y-%m-%d')

# %%
yahoo_financials = YahooFinancials('{}-INR'.format('BTC'))
btc_data=yahoo_financials.get_historical_price_data("2010-01-01", today, "daily")

# %%
def get_history(name):
  yahoo_financials = YahooFinancials('{}-INR'.format(name))
  data_his=yahoo_financials.get_historical_price_data("2010-01-01", today, "daily")
  df = pd.DataFrame(data_his['{}-INR'.format(name)]['prices'])
  df = df.drop('date', axis=1)
  df.rename(columns = {'formatted_date':'date'}, inplace = True)
  df=df[['date','high','low','open','close','volume']]
  return df

# %%
ab=get_history('BTC')

# %%
ab
# Out:
#             date          high           low          open         close  \
# 0     2014-09-17  2.854223e+04  2.755250e+04  2.844333e+04  2.785164e+04
# 1     2014-09-18  2.782277e+04  2.508574e+04  2.782277e+04  2.577412e+04
# 2     2014-09-19  2.598884e+04  2.336609e+04  2.575365e+04  2.402334e+04
# 3     2014-09-20  2.575756e+04  2.372438e+04  2.401585e+04  2.488181e+04
# 4     2014-09-21  2.509612e+04  2.392506e+04  2.483197e+04  2.426826e+04
# ...          ...           ...           ...           ...           ...
# 3069  2023-02-11  1.805803e+06  1.783413e+06  1.786168e+06  1.804109e+06
# 3070  2023-02-12  1.819792e+06  1.789100e+06  1.804111e+06  1.797795e+06
# 3071  2023-02-13  1.809542e+06  1.773391e+06  1.797695e+06  1.801311e+06
# 3072  2023-02-14  1.846251e+06  1.795219e+06  1.800792e+06  1.841390e+06
# 3073  2023-02-15  1.890175e+06  1.831548e+06  1.840174e+06  1.890175e+06
#
#              volume
# 0        1282359120
# 1        2093992320
# 2        2307413745
# ...

# %%
l1=['BTC','ETH','BNB','USDT','SOL','ADA','USDC','HEX','XRP','LUNA1']
#names=['Bitcoin','Ethereum','Binance','USDT']
def get_present_data(abvr):
  # define lists to hold the present data of different cryptos
  current_volume=[]
  market_cap=[]
  mov_avg_200=[]
  mov_avg_50=[]
  current_price=[]
  # iterating through the names and fetching the data
  for i in abvr:
    yahoo_financials = YahooFinancials('{}-INR'.format(i))
    vol=yahoo_financials.get_current_volume()
    cap=yahoo_financials.get_market_cap()
    ma_200=yahoo_financials.get_200day_moving_avg()
    ma_50=yahoo_financials.get_50day_moving_avg()
    cp=yahoo_financials.get_current_price()
    current_volume.append(vol)
    market_cap.append(cap)
    mov_avg_200.append(ma_200)
    mov_avg_50.append(ma_50)
    current_price.append(cp)

  # convert the data to dataframe
  df = pd.DataFrame(list(zip(abvr,current_price,current_volume,market_cap,mov_avg_200,mov_avg_50)),columns =['Abvr','current_price','current_volume','market_cap','MA_200','MA_50'])
  #df1.columns=['Symbol','current_price']
  #df1['Name']=name1 
  #df1.to_csv('Invested_cryptos.csv')
  return df

# %%
current_prices=get_present_data(abvr=l1)
current_prices
# Out:
#     Abvr  current_price  current_volume      market_cap        MA_200  \
# 0    BTC   1.831697e+06   2169465995264  35334775635968  1.602803e+06
# 1    ETH   1.283015e+05    774478561280  15700752072704  1.171228e+05
# 2    BNB   2.465181e+04     65062711296   3892486078464  2.339356e+04
# 3   USDT   8.299273e+01   3288677482496   5741633601536  8.135529e+01
# 4    SOL   1.819108e+03     70043836416    684785664000  2.078686e+03
# 5    ADA   3.127811e+01     31612411904   1083298807808  3.151010e+01
# 6   USDC   8.294127e+01    356541399040   3408455794688  8.136041e+01
# 7    HEX   4.068432e+00       959934464    705511227392  2.836912e+00
# 8    XRP   3.116059e+01     84341891072   1582929281024  3.227043e+01
# 9  LUNA1   2.369629e-02     39921471488    145757618176  1.629119e+03
#
#           MA_50
# 0  1.677193e+06
# 1  1.205728e+05
# 2  2.386686e+04
# 3  8.204944e+01
# 4  1.592563e+03
# 5  2.766279e+01
# 6  8.204771e+01
# 7  2.333606e+00
# 8  3.130574e+01
# 9  2.196180e-02

# %%
l2=['BTC-INR','ETH-INR','SOL-INR','SAND-INR','BAT-INR','MANA-INR','DOGE-INR']
current_price_invested=[]

for i in l2:
  yahoo_financials = YahooFinancials(i)
  cp=yahoo_financials.get_current_price()
  current_price_invested.append(cp)

# %%
df1 = pd.DataFrame(list(zip(l2,current_price_invested )),columns =['Name','current_price'])
df1.columns=['Symbol','current_price']
name1=['Bitcoin','Ethereum','Solana','Sandbox','BAT','Decentraland','Dogecoin']
df1['Name']=name1 
df1.to_csv('Invested_cryptos_current_prices.csv')

# %%
current_prices.to_csv('top_crypto_feb_14_2023.csv')

# %%
price_history=pd.DataFrame()
inv_cryp_abbr=['BTC','ETH','SOL','SAND','BAT','MANA','DOGE']
price_history_btc=get_history(inv_cryp_abbr[0])
price_history_eth=get_history(inv_cryp_abbr[1])
price_history_sol=get_history(inv_cryp_abbr[2])
price_history_sand=get_history(inv_cryp_abbr[3])
price_history_bat=get_history(inv_cryp_abbr[4])
price_history_mana=get_history(inv_cryp_abbr[5])
price_history_doge=get_history(inv_cryp_abbr[6])

# %%
price_history_btc.to_csv('Btc_price_data.csv')
price_history_eth.to_csv('Eth_price_data.csv')
price_history_sol.to_csv('Sol_price_data.csv')
price_history_sand.to_csv('Sand_price_data.csv')
price_history_bat.to_csv('Bat_price_data.csv')
price_history_mana.to_csv('Mana_price_data.csv')
price_history_doge.to_csv('Doge_price_data.csv')

# %%
yahoo_financials = YahooFinancials('{}-INR'.format("BTC"))
data=yahoo_financials.get_historical_price_data("2010-01-01", today, "daily")
pd.DataFrame(data['{}-INR'.format('BTC')]['prices'])
# Out:
#             date          high           low          open         close  \
# 0     1410912000  2.854223e+04  2.755250e+04  2.844333e+04  2.785164e+04
# 1     1410998400  2.782277e+04  2.508574e+04  2.782277e+04  2.577412e+04
# 2     1411084800  2.598884e+04  2.336609e+04  2.575365e+04  2.402334e+04
# 3     1411171200  2.575756e+04  2.372438e+04  2.401585e+04  2.488181e+04
# 4     1411257600  2.509612e+04  2.392506e+04  2.483197e+04  2.426826e+04
# ...          ...           ...           ...           ...           ...
# 3068  1675987200  1.811914e+06  1.776110e+06  1.800761e+06  1.786113e+06
# 3069  1676073600  1.805803e+06  1.783413e+06  1.786168e+06  1.804109e+06
# 3070  1676160000  1.819792e+06  1.789100e+06  1.804111e+06  1.797795e+06
# 3071  1676246400  1.809542e+06  1.773391e+06  1.797695e+06  1.801311e+06
# 3072  1676398406  1.846218e+06  1.796467e+06  1.800085e+06  1.835836e+06
#
#              volume      adjclose formatted_date
# ...

# %%
data['BTC-INR']['prices']
# Out:
# [{'date': 1676160000,
#   'high': 1819791.625,
#   'low': 1789100.0,
#   'open': 1804111.125,
#   'close': 1797794.75,
#   'volume': 1470455438225,
#   'adjclose': 1797794.75,
#   'formatted_date': '2023-02-12'},
#  {'date': 1676246400,
#   'high': 1809542.5,
#   'low': 1773390.875,
#   'open': 1797695.25,
#   'close': 1801311.0,
#   'volume': 1975646209814,
#   'adjclose': 1801311.0,
#   'formatted_date': '2023-02-13'},
#  {'date': 1676398046,
#   'high': 1846218.5,
#   'low': 1796466.625,
#   'open': 1800085.0,
#   'close': 1834246.625,
#   'volume': 2183203258368,
#   'adjclose': 1834246.625,
#   'formatted_date': '2023-02-14'}]

# %%
data['BTC-INR']
# Out:
# {'BTC-INR': {'eventsData': {},
#   'firstTradeDate': {'formatted_date': '2014-09-17', 'date': 1410912000},
#   'currency': 'INR',
#   'instrumentType': 'CRYPTOCURRENCY',
#   'timeZone': {'gmtOffset': 0},
#   'prices': [{'date': 1676160000,
#     'high': 1819791.625,
#     'low': 1789100.0,
#     'open': 1804111.125,
#     'close': 1797794.75,
#     'volume': 1470455438225,
#     'adjclose': 1797794.75,
#     'formatted_date': '2023-02-12'},
#    {'date': 1676246400,
#     'high': 1809542.5,
#     'low': 1773390.875,
#     'open': 1797695.25,
#     'close': 1801311.0,
#     'volume': 1975646209814,
#     'adjclose': 1801311.0,
#     'formatted_date': '2023-02-13'},
#    {'date': 1676393486,
#     'high': 1846218.5,
#     'low': 1796466.625,
#     'open': 1800085.0,
#     'close': 1824618.0,
#     'volume': 2200768610304,
#     'adjclose': 1824618.0,
#     'formatted_date': '2023-02-14'}]}}

# %%
pd.DataFrame(data['prices'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-80f0a0eb2a43> in <module>
# ----> 1 pd.DataFrame(data['prices'])
#
# KeyError: 'prices'

# %%
data
# Out:
# {'BTC-INR': {'eventsData': {},
#   'firstTradeDate': {'formatted_date': '2014-09-17', 'date': 1410912000},
#   'currency': 'INR',
#   'instrumentType': 'CRYPTOCURRENCY',
#   'timeZone': {'gmtOffset': 0},
#   'prices': [{'date': 1410912000,
#     'high': 28542.228515625,
#     'low': 27552.5,
#     'open': 28443.328125,
#     'close': 27851.640625,
#     'volume': 1282359120,
#     'adjclose': 27851.640625,
#     'formatted_date': '2014-09-17'},
#    {'date': 1410998400,
#     'high': 27822.7734375,
#     'low': 25085.740234375,
#     'open': 27822.7734375,
#     'close': 25774.119140625,
#     'volume': 2093992320,
#     'adjclose': 25774.119140625,
#     'formatted_date': '2014-09-18'},
#    {'date': 1411084800,
#     'high': 25988.8359375,
#     'low': 23366.087890625,
#     'open': 25753.654296875,
#     'close': 24023.3359375,
#     'volume': 2307413745,
#     'adjclose': 24023.3359375,
#     'formatted_date': '2014-09-19'},
#    {'date': 1411171200,
# ...
